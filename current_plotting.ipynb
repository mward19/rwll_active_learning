# %%
from plot_results import list_methods, plot_summary

# %%
list_methods("mnistimb-mod3", 3, "rwll", resultsdir="results")

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results",
    methods=[
        "mcvopt : rwll",
        "unc : rwll",
        "random : rwll0010",
        "uncnormprop++ : rwll0010",
        "vopt : rwll0010",
    ],
    show_std=True,
)
# Out:
# mcvopt : rwll
# random : rwll0010
# unc : rwll
# uncnorm : rwll0010
# uncnormdecaytau : rwll0010
# uncnormdecaytaukde : rwll0010
# uncnormprop++ : rwll0010
# uncnormprop++decaytau : rwll0010
# vopt : rwll0010

# %%
list_methods("mnistimb-mod3", 3, "rwll", resultsdir="results_test2")

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results_test2",
    methods=[
        "mcvopt : rwll",
        "unc : rwll",
        "random : rwll0010",
        "uncnormprop++ : rwll0010",
        "vopt : rwll0010",
    ],
    show_std=True,
)
# Out:
# mcvopt : rwll
# random : rwll0010
# unc : rwll
# uncnorm : rwll0010
# uncnormdecaytau : rwll0010
# uncnormdecaytaukde : rwll0010
# uncnormprop++ : rwll0010
# uncnormprop++decaytau : rwll0010
# vopt : rwll0010

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# mcvopt : rwll
# random : rwll0010
# unc : rwll
# uncnorm : rwll0010
# uncnormdecaytau : rwll0010
# uncnormdecaytaukde : rwll0010
# uncnormprop++ : rwll0010
# uncnormprop++decaytau : rwll0010
# vopt : rwll0010

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# mcvopt : rwll
# random : rwll0010
# unc : rwll
# uncnorm : rwll0010
# uncnormdecaytau : rwll0010
# uncnormdecaytaukde : rwll0010
# uncnormprop++ : rwll0010
# uncnormprop++decaytau : rwll0010
# vopt : rwll0010
