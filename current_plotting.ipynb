# %%
import importlib
from plot_results import list_methods, plot_summary

# %%
import plot_results
importlib.reload(plot_results)
from plot_results import list_methods, plot_summary, compare_methods_across_update_intervals, compare_methods_across_nn_layers

# uncnorm : rwll nn_layer 2
# random : rwll nn_layer 2
compare_methods_across_nn_layers(
    dataset="box",
    iters=60,
    modelname="rwll",
    resultsdir="results_box",
    config_path="temp.yaml",
    method='random : rwll',
    show_std=True,
    config_type="nn",
    nn_layers=[1,2,3,4],
    nn_update_interval=5
)

# %%
import plot_results
importlib.reload(plot_results)
from plot_results import list_methods, plot_summary, compare_methods_across_update_intervals

# uncnorm : rwll nn_layer 2
# random : rwll nn_layer 2
compare_methods_across_update_intervals(
    dataset="box",
    iters=60,
    modelname="rwll",
    resultsdir="results_box",
    config_path="temp.yaml",
    method='uncnormdecaytau : rwll0010',
    show_std=True,
    config_type="nn",
    nn_layer=2,
    nn_update_intervals=[0,5,50]
)

# %%
import plot_results
importlib.reload(plot_results)
from plot_results import list_methods, plot_summary
# list_methods(
#     dataset="mnistimb-mod3",
#     iters=10,
#     modelname="rwll",
#     resultsdir="results",
#     config_path="temp.yaml",
#     slurm_id=11535510
# )
plot_summary(
    dataset="blobs",
    iters=60,
    modelname="rwll",
    resultsdir="results_blobs",
    config_path="temp.yaml",
    show_std=True,
    config_type="nn",
    nn_layer=4,
    nn_update_interval=50
)
# Out:
# ['uncnormdecaytau : rwll0010']
# ['uncnormdecaytau : rwll0010', 'unc : rwll', 'random : rwll', 'uncnorm : rwll']

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=6,
    modelname="rwll",
    resultsdir="results3",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=6,
    modelname="rwll",
    resultsdir="results3",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll
# uncnormdecaytau : rwll0010

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll
# uncnormdecaytau : rwll0010

# %%
list_methods(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnistimb-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results5",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll

# %%
list_methods(
    dataset="mnist-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results6",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnist-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results6",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll

# %%
list_methods(
    dataset="mnist-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results6",
    config_path="config_mlp.yaml",
)

plot_summary(
    dataset="mnist-mod3",
    iters=3,
    modelname="rwll",
    resultsdir="results6",
    config_path="config_mlp.yaml",
    show_std=True,
)
# Out:
# random : rwll
# unc : rwll
# uncnorm : rwll
# uncnormdecaytau : rwll0010
